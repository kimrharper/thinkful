# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import calendar
from matplotlib.pyplot import subplots, show
import ast
import math
# %matplotlib inline

planecrash = pd.read_csv('plane_crashes_data.csv', encoding = "ISO-8859-1")

# %%
planecrash.aboard.mean()
# Out:
#       month hour  year                                           location  \
# 0         1   12  1950                                Near Vacas, Bolivia
# 1         3   20  1950                             Minneapolis, Minnesota
# 2         3   14  1950                    Llandow Airport, Cardiff, Wales
# 3         4   23  1950                                 Near Atsugi, Japan
# 4         5   20  1950                      Lagens Air Force Base, Azores
# 5         5   10  1950                       Myrtle Beach, South Carolina
# 6         5   17  1950                              Teterboro, New Jersey
# 7         6   22  1950                           AtlantiOcean off Florida
# 8         6   19  1950                             Near Fonseca, Colombia
# 9         6   21  1950                                        Off Bahrain
# 10        6   21  1950                                        Off Bahrain
# 11        6   23  1950   Lake Michigan, 18 NNW of Benton Harbor, Michigan
# ...

# %% [markdown]
# snakeeyes = 1/6 x 1/6 = 1/36

# %% [markdown]
# prob(snakeeyes) x prob(snakeeyes) x prob(snakeeyes)

# %% [markdown]
# lottery = (1/50 * 1/49 * 1/48 * 1/47) * (1/25)

# %%
crashesbyyear = planecrash['summary'].groupby(planecrash['year']).count()

# %%
plt.plot(crashesbyyear)

plt.show()

# %%
planecrash['fatalities'].mean()
# Out:
# 25.816537467700257

# %%
crashesbymonth = planecrash['summary'].groupby(planecrash['month']).count()
plt.plot(crashesbymonth)
plt.show()
# Out:
# 252

# %%
crashesbymonth
# Out:
# month
# 1     252
# 2     209
# 3     250
# 4     204
# 5     179
# 6     200
# 7     234
# 8     238
# 9     228
# 10    224
# 11    229
# 12    249
# Name: summary, dtype: int64

# %%
planecrash['fatalities'].max()
# Out:
# 583

# %%
planecrash['fatalities'].count()
# Out:
# 2709

# %%
zeroseries = planecrash[planecrash['fatalities'] == 0]
fatalities = planecrash[planecrash['fatalities'] > 0]

print(planecrash['fatalities'].isnull().sum())
# Out:
# 0

# %%
fatalities.count()
# Out:
# month         2660
# hour          2660
# year          2660
# location      2657
# operator      2658
# route         2279
# type          2659
# aboard        2660
# fatalities    2660
# summary       2647
# dtype: int64

# %%
2660/2709
# Out:
# 0.9819121447028424

# %%
planecrash['totalper'] = planecrash['fatalities'] / planecrash['aboard']

# %%
planecrash['totalper'].mean()
# Out:
# 0.8231319223510563
