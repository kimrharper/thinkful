# %% [markdown]
# Data Source: https://www.dropbox.com/s/pl5kcrhs2lyj90m/WELLCOME.zip?dl=0

# %% [markdown]
# <ol><li>determine the five most common journals and the total articles for each. <li>calculate the mean, median, and standard deviation of the open-access cost per article for each journal <li>identify the open access prices paid by subject area.

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from collections import Counter
import re

# %%
endspaces_find = re.compile(r'.*?(\s{1,2})$')
endspaces_remove = re.compile(r'\s$')
symbols_remove = re.compile(r'[^a-zA-Z0-9_\s]')
ampar = re.compile(r'[\&]')

# %%
def stringcorrection(strvalue):
    strvalue = str(strvalue).lower()
    
    if endspaces_find.match(strvalue):
        strvalue = endspaces_remove.sub('', strvalue)

    wordlist = strvalue.split(" ")
    wordlistfinal = []
    
    for word in wordlist:
        word = re.sub(ampar,'and', word)
        word = re.sub(r'[^\w]', '', word)
        
        if word != '':
            wordlistfinal.append(word)

    final = " ".join(wordlistfinal)
    
    return final

def symbolremove(strvalue):
    return re.sub(r'[\£|\$]', '', strvalue)

# %%
welcomedf = pd.read_csv('../data/WELLCOME_APCspend2013_forThinkful.csv',encoding = "ISO-8859-1")

# %%
welcomedf.loc[welcomedf['Journal title'] == 'Oxford University Press']
# Out:
#                PMID/PMCID                Publisher            Journal title  \
# 1256  23981980 PMC3809720  Oxford University Press  Oxford University Press
#
#                                           Article title  \
# 1256  Physical activity levels across adult life and...
#
#      COST (£) charged to Wellcome (inc VAT when charged)  \
# 1256                                         £999999.00
#
#                   Journalfix1      cost
# 1256  oxford university press  999999.0

# %%
len(welcomedf['Journal title'].unique())
# Out:
# 985

# %%
welcomedf['Journalfix1'] = welcomedf['Journal title'].apply(stringcorrection)
len(welcomedf['Journalfix1'].unique())
# Out:
# 874

# %%
welcomedf['cost'] = pd.to_numeric(welcomedf['COST (£) charged to Wellcome (inc VAT when charged)'].apply(symbolremove), 'float')

# %%
welcomedf.head()
# Out:
# cost    24067.339972
# dtype: float64

# %%
redf = pd.DataFrame(welcomedf[['cost','Journalfix1']])
journalsdf = pd.DataFrame(redf['cost'].groupby(redf['Journalfix1']).mean())

# %%
finalsort = pd.DataFrame(journalsdf['cost'].sort_values(ascending=False, axis=0))
finalsort
# Out:
#                                                              cost
# Journalfix1
# oxford university press                             999999.000000
# hbm jnl human brain mapping                         999999.000000
# expert reviews in molecular medicine                999999.000000
# frontiers in cognition                              999999.000000
# experimental cell research                          999999.000000
# poned1217947                                        999999.000000
# pmedicined1203130                                   999999.000000
# journal of paediatric urology                       999999.000000
# molecluar and cellular endocrinology                999999.000000
# the journal of cognitive neuroscience               999999.000000
# qualitative research                                999999.000000
# genetics in medicine                                501499.500000
# veterinary parasitology                             501243.585000
# trends in neurosciences                             501212.980000
# vision research                                     500727.590000
# molecular cell                                      402355.042000
# embo reports                                        335413.000000
# journal of the international african institute      334689.000000
# jnl biological chemistry                            333805.013333
# trends in parasitology                              251692.990000
# cell                                                202537.214000
# journal of neurochemistry                           201664.874000
# history of the human sciences                       201535.800000
# hippocampus                                         201341.816000
# trials                                              200960.180000
# bmc genomics                                        200908.500000
# pnas                                                167303.490000
# cerebral cortex                                     144666.285714
# journal of cell science                             126854.875000
# journal of physiology                               126783.231250
# ...                                                           ...
# acta dermato venereologica                             653.960000
# pnas usa                                               651.580000
# evidence ethos and experiment the anthropology ...     651.250000
# mol pharm                                              649.330000
# international journal of rheumatology                  626.000000
# frontiers in neurorobotics                             625.200000
# journal of parasitology research                       623.950000
# proceddings of the national academy of sciences...     619.830000
# autophagy                                              601.100000
# journal of historical geography                        596.460000
# health                                                 551.270000
# theranostics                                           543.290000
# journal of visualized experiements                     517.500000
# epigentics                                             508.660000
# epigenetics                                            490.485000
# rna biology                                            490.123333
# neuroscientist                                         480.930000
# frontiers in cognitive science                         434.700000
# j infect dis                                           378.780000
# haematologicathe haematology journal                   378.700000
# frontiers in genetics                                  346.250000
# physics in biology and medicine                        340.000000
# cell adhesion and migration                            321.460000
# essays in biochemistry                                 270.000000
# international journal of financial research            187.030000
# journal of neurology and translational neurosci...     159.910000
# channels                                               159.740000
# journal of biomedical graphics and computing           135.290000
# american society for nutrition                          45.940000
# veterinary research                                      9.930000
#
# [874 rows x 1 columns]

# %%
spelling_errors = {'jounral':'journal', 'heath':'health','molecular':'mol', 'society':'soc','human':'hum','humanan':'human',
                   'biol':'biology', 'chemical':'chem','biolgy':'biology', 'service':'services',
                   'organic':'org','americal':'american','bioohysica':'biophysica','journal':'j'}

pattern = re.compile(r'\b(' + '|'.join(spelling_errors.keys()) + r')\b')

def publisher_fix(seriesvalue):
       
    seriesvalue = seriesvalue.lower()
    
    if endspaces_find.match(seriesvalue):
        seriesvalue = endspaces_remove.sub('', seriesvalue)
    if re.match(r'national academy of sciences', seriesvalue):
        seriesvalue = 'national academy of sciences'
    if re.match(r'acs', seriesvalue):
        seriesvalue = 'acs'
    if re.match(r'nature', seriesvalue):
        seriesvalue = 'nature'
    if re.match(r'cell press', seriesvalue):
        seriesvalue = 'cell press'
    if re.match(r'bmj', seriesvalue):
        seriesvalue = 'bmj'
    if re.match(r'taylor', seriesvalue):
        seriesvalue = 't&f'
    if re.match(r'wolters', seriesvalue):
        seriesvalue = 'wolters kluwer'
    if re.match(r'wiley', seriesvalue):
        seriesvalue = 'wiley'
        
    return seriesvalue


# def journal_fix(seriesvalue):
#     seriesvalue = str(seriesvalue)
#     seriesvalue = seriesvalue.replace("&", "and")
    
#     seriesvalue = seriesvalue.lower()
    
#     if endspaces_find.match(seriesvalue):
#         seriesvalue = endspaces_remove.sub('', seriesvalue)
        
        
#     if pattern.match(seriesvalue):
# #         print(seriesvalue)
#         seriesvalue = pattern.sub(lambda x: spelling_errors[x.group()], seriesvalue)
# #         print(seriesvalue)
            
#     return seriesvalue

welcomedf['Journalfix2'] = welcomedf['Journal title'].apply(journal_fix)
welcomedf['Journalfix2'].value_counts()



welcomedf['Journalfix1'] = welcomedf['Journal title'].apply(correction)
welcomedf['Journalfix1'].value_counts()

welcomedf.Publisher = welcomedf.Publisher.apply(publisher_fix)
