# %%
import pandas as pd

# %%
timeseries1 = pd.read_csv('../data/timeseries/medianincome.csv')
timeseries2 = pd.read_csv('../data/timeseries/gdp.csv')
timeseries1.index = pd.to_datetime(timeseries1.DATE)
timeseries2.index = pd.to_datetime(timeseries2.DATE)

# %%
timeseries1.MEHOINUSA672N = timeseries1.MEHOINUSA672N/10000

# %%
mergeddf = pd.merge(timeseries1, timeseries2, how='left', on='DATE');
# Out:
# /Users/ryan/.local/share/virtualenvs/thinkful-Xo17phXs/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2961: FutureWarning: 'DATE' is both an index level and a column label.
# Defaulting to column, but this will raise an ambiguity error in a future version
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
mergeddf.plot();

# %%
pd.plot()
